# %% [markdown]
# <a href="https://colab.research.google.com/github/arizbesilva0-star/Programacion-2026/blob/main/teoria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Te damos la bienvenida a Colab

# %% [markdown]
# # Clase con la profesora-Ejercicio con el operador punto
#
# *   Elemento de la lista
# *   Elemento de la lista
#
#
# Miercoles 17 de Febrero 2026

# %%
#@autor:arizsil #Cuenta.py
class Cuenta :
  #este es el metodo constructor, que
  #inicializa a los atributos de una clase
  def __init__(self, valor) :
    self.saldo=valor

# %%
# Menu.py
class Menu:
  pass
print("Desde el Menu")
cuenta1=Cuenta(3000,)
print(cuenta1.saldo)
# Out:
# Desde el Menu
# 3000

# %% [markdown]
# Eso fue lo que se vio en clase, de tarea es agregar el tpo de cuenta que puede ser c=credito o d=debito

# %%
#@autor:arizsil #Cuenta.py
class Cuenta :
  #este es el metodo constructor, que
  #inicializa a los atributos de una clase
  def __init__(self, valor, tipo) :
    self.saldo=valor
    self.tipo=tipo

# %%
# Menu.py
class Menu:
  pass
print("Desde el Menu")
cuenta1=Cuenta(3000, "c")
print(cuenta1.saldo)
print(cuenta1.tipo)
# Out:
# Desde el Menu
# 3000
# c

# %% [markdown]
# # Clase con la profesora
# Jueves 19 de Febrero 2026

# %% [markdown]
# Ahora en esta clase agregaremos el metodo de depositar.
#
# en el [5] para pyton hay que escribir abajo de
#
# poner #from Cuenta impot
# abajo del primer #

# %%
#@autor:arizsil #Cuenta.py
class Cuenta :
  #este es el metodo constructor, que
  #inicializa a los atributos de una clase
  def __init__(self, valor1, valor2) :
    self.saldo=valor1
    self.tipo=valor2
  def depositar(self, cantidad) :
    self.saldo=self.saldo+cantidad
  def retirar(self, cantidad2) :
    self.saldo=self.saldo-cantidad2

# %%
# Menu.py
class Menu:
  pass
print("Probando el objeto")
cuenta1=Cuenta(3000, "c")
print(cuenta1.saldo)
print(cuenta1.tipo)
cuenta1.depositar(5000)
print("Pobando el deposito")
print(cuenta1.saldo)
cuenta1.retirar(1200)
print("Probando el retiro")
print(cuenta1.saldo)
# Out:
# Probando el objeto
# 3000
# c
# Pobando el deposito
# 8000
# Probando el retiro
# 6800
